# %%
import numpy as np
import tensorflow as tf
import tensorflow.keras.datasets as ds

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

(x_train,y_train),(x_test,y_test)=ds.mnist.load_data()
x_train=x_train.reshape(60000,784)
x_test=x_test.reshape(10000,784)
x_train=x_train.astype(np.float32)/255.0
x_test=x_test.astype(np.float32)/255.0
y_train=tf.keras.utils.to_categorical(y_train,10)
y_test=tf.keras.utils.to_categorical(y_test,10)

learning_rates = [0.1, 0.01, 0.001, 0.0001, 0.00001] # 학습률들을 리스트로 추가

for lr in learning_rates: #반복문을 이용하여 학습률을 대입
    mlp=Sequential()
    mlp.add(Dense(units=512,activation='tanh',input_shape=(784,)))
    mlp.add(Dense(units=10,activation='softmax'))

    mlp.compile(loss='MSE',optimizer=Adam(learning_rate=lr),metrics=['accuracy'])
    mlp.fit(x_train,y_train,batch_size=128,epochs=50,validation_data=(x_test,y_test),verbose=2)

    res=mlp.evaluate(x_test,y_test,verbose=0)
    print(f'학습률 {lr}일 때 정확률={res[1]*100:.2f}%')
# Out:
# Epoch 1/50
# 469/469 - 1s - loss: 0.1775 - accuracy: 0.1096 - val_loss: 0.1794 - val_accuracy: 0.1028 - 1s/epoch - 3ms/step
# Epoch 2/50
# 469/469 - 1s - loss: 0.1791 - accuracy: 0.1044 - val_loss: 0.1794 - val_accuracy: 0.1028 - 1s/epoch - 3ms/step
# Epoch 3/50
# 469/469 - 1s - loss: 0.1791 - accuracy: 0.1044 - val_loss: 0.1794 - val_accuracy: 0.1028 - 1s/epoch - 3ms/step
# Epoch 4/50
# 469/469 - 1s - loss: 0.1791 - accuracy: 0.1044 - val_loss: 0.1794 - val_accuracy: 0.1028 - 1s/epoch - 3ms/step
# Epoch 5/50
# 469/469 - 1s - loss: 0.1791 - accuracy: 0.1044 - val_loss: 0.1794 - val_accuracy: 0.1028 - 1s/epoch - 3ms/step
# Epoch 6/50
# 469/469 - 1s - loss: 0.1791 - accuracy: 0.1044 - val_loss: 0.1794 - val_accuracy: 0.1028 - 1s/epoch - 3ms/step
# Epoch 7/50
# 469/469 - 1s - loss: 0.1791 - accuracy: 0.1044 - val_loss: 0.1794 - val_accuracy: 0.1028 - 1s/epoch - 3ms/step
# Epoch 8/50
# ...
